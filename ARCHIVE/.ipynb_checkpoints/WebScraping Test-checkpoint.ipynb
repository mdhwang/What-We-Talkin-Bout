# %%
import copy
import pandas as pd

# Requests sends and recieves HTTP requests.
import requests

# Beautiful Soup parses HTML documents in python.
from bs4 import BeautifulSoup

# %%
birthday_song_url = 'https://www.azlyrics.com/lyrics/2chainz/birthdaysong.html'
r = requests.get(birthday_song_url)
r.content
type(r)
# Out:
# requests.models.Response

# %%
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Lyrics to &quot;Birthday Song&quot; song by 2 Chainz: Yeah Birthday, it's your birthday If I die bury me inside the Louis store They ask me what I do an..." name="description"/>
# <meta content="Birthday Song lyrics, 2 Chainz Birthday Song lyrics, 2 Chainz lyrics" name="keywords"/>
# <meta content="noarchive" name="robots"/>
# <meta content="//www.azlyrics.com/az_logo_tr.png" property="og:image"/>
# <title>2 Chainz - Birthday Song Lyrics | AZLyrics.com</title>
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="//www.azlyrics.com/bsaz.css" rel="stylesheet"/>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
# ...

# %%
so_pretty = soup.prettify()

# %%
first_split = so_pretty.split("<!-- Usage of azlyrics.com content by any third-party lyrics provider is prohibited by our licensing agreement. Sorry about that. -->")

# %%
lyrics = first_split[1].split("<!-- MxM banner -->")[0]
lyrics
# Out:
# '\n      <i>\n       [2 Chainz:]\n      </i>\n      <br/>\n      Yeah\n      <br/>\n      Birthday, it\'s your birthday\n      <br/>\n      If I die bury me inside the Louis store\n      <br/>\n      <br/>\n      <i>\n       [2 Chainz:]\n      </i>\n      <br/>\n      They ask me what I do and who I do it for (yeah)\n      <br/>\n      And how I come up with this shit up in the studio (yeah)\n      <br/>\n      All I want for my birthday is a big booty ho (true)\n      <br/>\n      All I want for my birthday is a big booty ho (tell \'em)\n      <br/>\n      When I die, bury me inside the Gucci store (tell \'em)\n      <br/>\n      When I die, bury me inside the Louis store (true)\n      <br/>\n      All I want for my birthday is a big booty ho (yeah)\n      <br/>\n      All I want for my birthday is a big booty ho (2 Chainz!)\n      <br/>\n      <br/>\n      <i>\n       [2 Chainz:]\n      </i>\n      <br/>\n      She got a big booty so I call her Big Booty (booty)\n      <br/>\n     
# ...

# %%
htmlshit = ["\n","<i>","</i>","<br/>","</div>",'\"']

for each in htmlshit:
    lyrics = lyrics.replace(each,'')

split = lyrics.split()
import pandas as pd

birthday = pd.DataFrame(split)

birthday.columns = ["Words"]
birthday["Word Count"] = 1

# %%
birthday.head()
# Out:
#        Words  Word Count
# 0         [2           1
# 1   Chainz:]           1
# 2       Yeah           1
# 3  Birthday,           1
# 4       it's           1

# %%
g = birthday.groupby("Words")

# %%
g.count().sort_values("Word Count",ascending=False)
# Out:
#              Word Count
# Words
# I                    55
# a                    30
# the                  29
# for                  21
# my                   19
# me                   18
# booty                18
# birthday             18
# big                  17
# All                  16
# ho                   16
# is                   16
# want                 16
# in                   16
# you                  14
# (yeah)               13
# bury                 13
# inside               12
# die,                 12
# and                  12
# When                 12
# it                   12
# store                11
# do                   10
# (true)               10
# up                   10
# to                    9
# [2                    8
# (tell                 8
# 'em)                  8
# ...                 ...
# Chainz!)              1
# Booty                 1
# Birthday,             1
# Ye                    1
# jokin',               1
# End?                  1
# ...
