# %%
import copy
import pandas as pd

# Requests sends and recieves HTTP requests.
import requests

# Beautiful Soup parses HTML documents in python.
from bs4 import BeautifulSoup

# %%
letter = 'https://www.azlyrics.com/p.html'
r = requests.get(letter)
type(r)
# Out:
# requests.models.Response

# %%
soup = BeautifulSoup(r.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
# <meta content="noarchive" name="robots"/>
# <title>Artists P at AZLyrics</title>
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="//www.azlyrics.com/bsaz.css" rel="stylesheet"/>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
#       <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#       <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
# <link href="//www.azlyrics.com/local/cookieconsent/cookieconsent.min.css" rel="stylesheet"/>
# ...

# %%
links = []
for each in soup.find_all('a'):
    links.append(each.get("href"))

# %%
links = links[28:-8]
# Out:
# ['p/p9.html',
#  'a/anderson-paak.html',
#  'p/pabloalboran.html',
#  'p/pacdiv.html',
#  'm/michelapace.html',
#  'p/pack.html',
#  'p/padi.html',
#  'b/belapadilla.html',
#  'd/danielpadilla.html',
#  'p/pagano.html',
#  'p/pagefrance.html',
#  't/tashapagelockhart.html',
#  'm/morganpage.html',
#  't/tommypage.html',
#  'f/florentpagny.html',
#  'c/carlypaige.html',
#  'j/jenniferpaige.html',
#  'm/madilynpaige.html',
#  'p/pain.html',
#  'p/painofsalvation.html',
#  'p/painsofbeingpureatheart.html',
#  'p/paisley.html',
#  'p/palayeroyale.html',
#  'p/palewaves.html',
#  'p/palisades.html',
#  'n/nerinapallot.html',
#  'p/palmaviolets.html',
#  'a/amandapalmer.html',
#  'k/kekepalmer.html',
#  'r/robertpalmer.html',
#  'p/palms.html',
#  'p/palmtrees.html',
#  'p/palomafaith.html',
#  'p/palomamami.html',
#  'g/gwynethpaltrow.html',
#  'p/pamtillis.html',
#  'p/panama.html',
#  'p/pandabear.html',
#  'r/rendypandugo.html',
#  'r/roopanes.html',
#  'h/haydenpanettiere.html',
# ...

# %%
len(links)
# Out:
# 534

# %%
home_url = "https://www.azlyrics.com/"
for i,each in enumerate(links):
     links[i] = each.replace("..",home_url)

# %%
links
# Out:
# ['https://www.azlyrics.com//lyrics/postmalone/neverunderstand.html',
#  'https://www.azlyrics.com//lyrics/postmalone/moneymademedoit.html',
#  'https://www.azlyrics.com//lyrics/postmalone/gitwitu.html',
#  'https://www.azlyrics.com//lyrics/postmalone/goddamn.html',
#  'https://www.azlyrics.com//lyrics/postmalone/fuck.html',
#  'https://www.azlyrics.com//lyrics/postmalone/40funk.html',
#  'https://www.azlyrics.com//lyrics/postmalone/monte.html',
#  'https://www.azlyrics.com//lyrics/postmalone/hollywooddreamscomedown.html',
#  'https://www.azlyrics.com//lyrics/postmalone/lonely.html',
#  'https://www.azlyrics.com//lyrics/postmalone/ohgod.html',
#  'https://www.azlyrics.com//lyrics/postmalone/brokenwhiskeyglass.html',
#  'https://www.azlyrics.com//lyrics/postmalone/biglie.html',
#  'https://www.azlyrics.com//lyrics/postmalone/dejavu.html',
#  'https://www.azlyrics.com//lyrics/postmalone/nooption.html',
#  'https://www.azlyrics.com//lyrics/postmalone/cold.html',
# ...

# %% [markdown]
# # THIS IS IT

# %%
def get_artist_links(letter_url):
    soup = BeautifulSoup(requests.get(letter_url).content, 'html.parser') #get that shit
    links = []
    home_url = "https://www.azlyrics.com/"
    for each in soup.find_all('a'):
        links.append(home_url + each.get("href")) #store that shit
    return links[28:-8] #takes out nav links and footer links, return that shit

# %% [markdown]
# # TEST OF IT

# %%
letter = 'https://www.azlyrics.com/p.html'

test = get_artist_links(letter)
test
# Out:
# ['https://www.azlyrics.com/p/p9.html',
#  'https://www.azlyrics.com/a/anderson-paak.html',
#  'https://www.azlyrics.com/p/pabloalboran.html',
#  'https://www.azlyrics.com/p/pacdiv.html',
#  'https://www.azlyrics.com/m/michelapace.html',
#  'https://www.azlyrics.com/p/pack.html',
#  'https://www.azlyrics.com/p/padi.html',
#  'https://www.azlyrics.com/b/belapadilla.html',
#  'https://www.azlyrics.com/d/danielpadilla.html',
#  'https://www.azlyrics.com/p/pagano.html',
#  'https://www.azlyrics.com/p/pagefrance.html',
#  'https://www.azlyrics.com/t/tashapagelockhart.html',
#  'https://www.azlyrics.com/m/morganpage.html',
#  'https://www.azlyrics.com/t/tommypage.html',
#  'https://www.azlyrics.com/f/florentpagny.html',
#  'https://www.azlyrics.com/c/carlypaige.html',
#  'https://www.azlyrics.com/j/jenniferpaige.html',
#  'https://www.azlyrics.com/m/madilynpaige.html',
#  'https://www.azlyrics.com/p/pain.html',
#  'https://www.azlyrics.com/p/painofsalvation.html',
# ...

# %%
len(test)
# Out:
# 534
